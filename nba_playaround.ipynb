# %%
import pandas as pd
import numpy as np

df = pd.read_csv('FanDuel-NBA-2020-02-01-43204-players-list.csv')
df.head()
# Out:
#             Id Position First Name        Nickname Last Name       FPPG  \
# 0   43204-9488       SF     LeBron    LeBron James     James  51.911111
# 1  43204-84669       PG       Luka     Luka Doncic    Doncic  52.653491
# 2  43204-15755       PF    Anthony   Anthony Davis     Davis  52.379999
# 3  43204-20848       PG     Damian  Damian Lillard   Lillard  47.548937
# 4  43204-84671       PG       Trae      Trae Young     Young  47.781816
#
#    Played  Salary     Game Team Opponent Injury Indicator Injury Details  \
# 0      45   11000  LAL@SAC  LAL      SAC              NaN            NaN
# 1      43   10500  ATL@DAL  DAL      ATL                O          Ankle
# 2      40   10300  LAL@SAC  LAL      SAC              NaN            NaN
# 3      47   10200  UTA@POR  POR      UTA              NaN            NaN
# 4      44    9900  ATL@DAL  ATL      DAL              NaN            NaN
#
#    Tier  Unnamed: 14  Unnamed: 15
# 0   NaN          NaN          NaN
# ...

# %%
dfpg = df.loc[df['Position'] == "SF"]
df
# Out:
#                Id Position First Name                Nickname       Last Name  \
# 0      43204-9488       SF     LeBron            LeBron James           James
# 28    43204-14518       SF     Tobias           Tobias Harris          Harris
# 32    43204-12366       SF     Gordon          Gordon Hayward         Hayward
# 35    43204-67026       SF     Jaylen            Jaylen Brown           Brown
# 38    43204-23120       SF       T.J.             T.J. Warren          Warren
# ..            ...      ...        ...                     ...             ...
# 279   43204-15758       SF    Michael  Michael Kidd-Gilchrist  Kidd-Gilchrist
# 283   43204-80811       SF   Jonathan          Jonathan Isaac           Isaac
# 290    43204-9677       SF      Jared            Jared Dudley          Dudley
# 291  43204-101327       SF         BJ              BJ Johnson         Johnson
# 295   43204-48598       SF       Semi            Semi Ojeleye         Ojeleye
#
# ...

# %%
#try every combination
    #5 tables for each position
#exceeeding limit then remove
#if can replace non-desired with desired then remove
#sort by money left over
