# %%
# trend when market starting to peak?
# trend when market just starting to increase
# trend supply of houses during recession and not



import pandas as pd
pd.options.display.max_columns = 9999
pd.options.display.max_rows = 10
df = pd.read_csv('Zip_Zhvi_4bedroom.csv', encoding='latin')

# %%
df.head()
# Out:
#    RegionID  RegionName      City State                             Metro  \
# 0     61639       10025  New York    NY       New York-Newark-Jersey City
# 1     84654       60657   Chicago    IL          Chicago-Naperville-Elgin
# 2     61637       10023  New York    NY       New York-Newark-Jersey City
# 3     91982       77494      Katy    TX  Houston-The Woodlands-Sugar Land
# 4     84616       60614   Chicago    IL          Chicago-Naperville-Elgin
#
#         CountyName  SizeRank   1996-04   1996-05   1996-06   1996-07  \
# 0  New York County         1       NaN       NaN       NaN       NaN
# 1      Cook County         2  397764.0  396109.0  396150.0  396062.0
# 2  New York County         3       NaN       NaN       NaN       NaN
# 3    Harris County         4  189033.0  188178.0  187993.0  188078.0
# 4      Cook County         5  517151.0  514986.0  515402.0  515453.0
#
#     1996-08   1996-09   1996-10   1996-11   1996-12   1997-01   1997-02  \
# ...

# %%
def growth(row):
    if ( (float(row['2020-01']) > (row['2019-01'] * 1.05) ) & (row['2019-01'] > (row['2018-01'] * 1.05)) ):
        row['growing'] = 1
    else:
        row['growing'] = 0
    return row

df_growing = df.apply(lambda row: growth(row), axis='columns')

df_growing = df_growing[df_growing['growing'] == 1]

# %%
df_growing
# Out:
#        RegionID  RegionName          City State  \
# 11        61807       10467      New York    NY
# 36        71067       30349     Riverdale    GA
# 41        62017       11206      New York    NY
# 43        96027       90046   Los Angeles    CA
# 48        61802       10462      New York    NY
# ...         ...         ...           ...   ...
# 26750     78588       47405   Bloomington    IN
# 26763     94098       83281        Downey    ID
# 26765     59376        4109      Portland    ME
# 26771     98400       95721  Twin Bridges    CA
# 26775     66169       20052    Washington    DC
#
#                                      Metro            CountyName  SizeRank  \
# 11             New York-Newark-Jersey City          Bronx County        12
# 36           Atlanta-Sandy Springs-Roswell        Clayton County        37
# 41             New York-Newark-Jersey City          Kings County        42
# 43          Los Angeles-Long Beach-Anaheim    Los Angeles County        44
# ...

# %%
growing_states = df_growing.groupby('State')['growing'].agg([sum, len])
growing_states = growing_states.reset_index()
growing_states = growing_states[['State','len']]
growing_states = growing_states.rename(columns = {'len':'growingcount'})
growing_states
# Out:
#    State  growingcount
# 0     AK             7
# 1     AL            76
# 2     AR            38
# 3     AZ           145
# 4     CA           193
# ..   ...           ...
# 45    VT            10
# 46    WA           230
# 47    WI           193
# 48    WV            36
# 49    WY            24
#
# [50 rows x 2 columns]

# %%
state_all = df.groupby('State').size()
state_all
dfs = state_all.reset_index()
dfs = dfs.rename(columns = {0:'fullcount'})

# %%
dfstate = dfs.merge(growing_states, left_on = 'State', right_on = 'State')
dfstate
# Out:
#    State  fullcount  growingcount
# 0     AK         46             7
# 1     AL        481            76
# 2     AR        335            38
# 3     AZ        300           145
# 4     CA       1559           193
# ..   ...        ...           ...
# 45    VT        224            10
# 46    WA        516           230
# 47    WI        713           193
# 48    WV        529            36
# 49    WY        124            24
#
# [50 rows x 3 columns]

# %%
pd.options.display.max_rows = 99
dfstate['growingratio'] = dfstate['growingcount']/dfstate['fullcount']
dfstate = dfstate.sort_values('growingratio', ascending=False)
dfstate
# Out:
#    State  fullcount  growingcount  growingratio
# 12    ID        233           182      0.781116
# 43    UT        190           100      0.526316
# 3     AZ        300           145      0.483333
# 46    WA        516           230      0.445736
# 14    IN        743           309      0.415882
# 25    MT        224            82      0.366071
# 41    TN        562           183      0.325623
# 34    OH       1096           349      0.318431
# 47    WI        713           193      0.270687
# 28    NE        389            96      0.246787
# 36    OR        359            87      0.242340
# 21    MI        882           208      0.235828
# 20    ME        330            72      0.218182
# 23    MO        759           159      0.209486
# 35    OK        531           110      0.207156
# 9     GA        638           127      0.199060
# 49    WY        124            24      0.193548
# 40    SD        140            27      0.192857
# 7     DC         21             4      0.190476
# ...

# %%
pd.options.display.max_rows = 5
df_growing
# Out:
#        RegionID  RegionName          City State  \
# 11        61807       10467      New York    NY
# 36        71067       30349     Riverdale    GA
# ...         ...         ...           ...   ...
# 26771     98400       95721  Twin Bridges    CA
# 26775     66169       20052    Washington    DC
#
#                                      Metro            CountyName  SizeRank  \
# 11             New York-Newark-Jersey City          Bronx County        12
# 36           Atlanta-Sandy Springs-Roswell        Clayton County        37
# ...                                    ...                   ...       ...
# 26771  Sacramento--Roseville--Arden-Arcade      El Dorado County     26772
# 26775      Washington-Arlington-Alexandria  District of Columbia     26776
#
#         1996-04   1996-05   1996-06   1996-07   1996-08   1996-09   1996-10  \
# 11     319980.0  320680.0  317494.0  316305.0  312710.0  310961.0  309790.0
# ...

# %%
pd.options.display.max_rows = 99
df_growing.loc[df_growing['State'] == 'NY']
# Out:
#        RegionID  RegionName                 City State  \
# 11        61807       10467             New York    NY
# 41        62017       11206             New York    NY
# 48        61802       10462             New York    NY
# 49        61796       10456             New York    NY
# 96        61798       10458             New York    NY
# 110       61793       10453             New York    NY
# 181       61808       10468             New York    NY
# 232       61797       10457             New York    NY
# 498       62014       11203             New York    NY
# 543       63414       14094      North Tonawanda    NY
# 698       61806       10466             New York    NY
# 709       61800       10460             New York    NY
# 785       61934       10940           Middletown    NY
# 788       61812       10472             New York    NY
# 789       61813       10473             New York    NY
# 813       62658       12550     Town of Newburgh    NY
# ...

# %%
df.describe()
# Out:
#             RegionID    RegionName     SizeRank       1996-04       1996-05  \
# count   26778.000000  26778.000000  26778.00000  1.178000e+04  1.184700e+04
# mean    80156.596609  48016.959108  13389.50000  1.600965e+05  1.601406e+05
# std     26008.207753  27505.395564   7730.28709  9.934844e+04  9.916173e+04
# min     58076.000000    734.000000      1.00000  1.943100e+04  1.944900e+04
# 25%     68464.250000  25082.250000   6695.25000  9.819925e+04  9.833250e+04
# 50%     78638.500000  47404.500000  13389.50000  1.397575e+05  1.400310e+05
# 75%     88629.750000  70358.750000  20083.75000  1.944602e+05  1.942685e+05
# max    753844.000000  99901.000000  26778.00000  2.386276e+06  2.379852e+06
#
#             1996-06       1996-07       1996-08       1996-09       1996-10  \
# count  1.186400e+04  1.188700e+04  1.190900e+04  1.192600e+04  1.194400e+04
# mean   1.603289e+05  1.606288e+05  1.608201e+05  1.611374e+05  1.614648e+05
# ...
